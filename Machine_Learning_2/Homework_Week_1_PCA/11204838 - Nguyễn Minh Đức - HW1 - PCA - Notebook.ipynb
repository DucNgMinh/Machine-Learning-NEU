# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import decomposition
from sklearn.datasets import load_iris
from Machine_Learning_2.Homework_Week_1_PCA import PCA

# %%
df = load_iris().data
target = pd.DataFrame(load_iris().target, columns= ['Target'])
PCA = PCA.PCA(n_components = 2)

# %%
reduced_iris = PCA.fit_transform(df)
reduced_iris = pd.DataFrame(reduced_iris, columns=['PCA1', 'PCA2'])
reduced_iris
# Out:
#          PCA1      PCA2
# 0   -2.684126 -0.319397
# 1   -2.714142  0.177001
# 2   -2.888991  0.144949
# 3   -2.745343  0.318299
# 4   -2.728717 -0.326755
# ..        ...       ...
# 145  1.944110 -0.187532
# 146  1.527167  0.375317
# 147  1.764346 -0.078859
# 148  1.900942 -0.116628
# 149  1.390189  0.282661
#
# [150 rows x 2 columns]

# %%
reduced_iris = pd.concat([reduced_iris, target], axis=1)
reduced_iris
# Out:
#          PCA1      PCA2  Target
# 0   -2.684126 -0.319397       0
# 1   -2.714142  0.177001       0
# 2   -2.888991  0.144949       0
# 3   -2.745343  0.318299       0
# 4   -2.728717 -0.326755       0
# ..        ...       ...     ...
# 145  1.944110 -0.187532       2
# 146  1.527167  0.375317       2
# 147  1.764346 -0.078859       2
# 148  1.900942 -0.116628       2
# 149  1.390189  0.282661       2
#
# [150 rows x 3 columns]

# %%
plt.figure(figsize= (6,6))
sns.scatterplot(x=reduced_iris['PCA1'], y= reduced_iris['PCA2'], hue=reduced_iris['Target'], palette= 'deep').set_title('PCA from scratch')
# Out:
# Text(0.5, 1.0, 'PCA from scratch')

# %%
var_explain, cumulative_var = PCA.explained_variance_raito()

# %%
plt.plot(range(0,len(cumulative_var) + 1), np.concatenate(([0],cumulative_var)))
plt.ylabel('Cumulative explained variance')
plt.legend(loc='best')
plt.title('Explained variance')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
pca = decomposition.PCA(n_components=2)
reduced_iris1 =pca.fit_transform(df)

# %%
reduced_iris1 = pd.DataFrame(reduced_iris1, columns=['PCA1', 'PCA2'])
reduced_iris1
# Out:
#          PCA1      PCA2
# 0   -2.684126  0.319397
# 1   -2.714142 -0.177001
# 2   -2.888991 -0.144949
# 3   -2.745343 -0.318299
# 4   -2.728717  0.326755
# ..        ...       ...
# 145  1.944110  0.187532
# 146  1.527167 -0.375317
# 147  1.764346  0.078859
# 148  1.900942  0.116628
# 149  1.390189 -0.282661
#
# [150 rows x 2 columns]

# %%
reduced_iris1 = pd.concat([reduced_iris1, target], axis=1)
reduced_iris1
# Out:
#          PCA1      PCA2  Target
# 0   -2.684126  0.319397       0
# 1   -2.714142 -0.177001       0
# 2   -2.888991 -0.144949       0
# 3   -2.745343 -0.318299       0
# 4   -2.728717  0.326755       0
# ..        ...       ...     ...
# 145  1.944110  0.187532       2
# 146  1.527167 -0.375317       2
# 147  1.764346  0.078859       2
# 148  1.900942  0.116628       2
# 149  1.390189 -0.282661       2
#
# [150 rows x 3 columns]

# %%
plt.figure(figsize= (6,6))
sns.scatterplot(x=reduced_iris1['PCA1'], y= reduced_iris1['PCA2'], hue=reduced_iris1['Target'], palette= 'deep').set_title('PCA from sklearn')
# Out:
# Text(0.5, 1.0, 'PCA from sklearn')

# %%
pca.components_
# Out:
# array([[ 0.36138659, -0.08452251,  0.85667061,  0.3582892 ],
#        [ 0.65658877,  0.73016143, -0.17337266, -0.07548102]])

# %%
PCA.get_components()
# Out:
# array([[ 0.36138659, -0.65658877],
#        [-0.08452251, -0.73016143],
#        [ 0.85667061,  0.17337266],
#        [ 0.3582892 ,  0.07548102]])
